# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, Input, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import numpy as np
import matplotlib.pyplot as plt
import pathlib

import functions_ai

# %%
print(os.getcwd())
# Out:
# /Users/axellepetit/Desktop/projectAI

# %%
#metrics = accuracy (basic) and RECALL

# Set random seed
np.random.seed(42)
tf.random.set_seed(42)

# %%
custom_preprocessing = functions_ai.custom_preprocessing
batch_size = 128
img_height = img_width = 299

#set the paths/directories
path = pathlib.Path('covid xray')
train_dir = os.path.join(path, 'train') #just gives the path 
validation_dir = os.path.join(path, 'val')
test_dir = os.path.join(path, 'test')

train_covid_dir = os.path.join(train_dir, 'COVID')
train_normal_dir = os.path.join(train_dir, 'NORMAL')

validation_covid_dir = os.path.join(validation_dir, 'COVID')
validation_normal_dir = os.path.join(validation_dir, 'NORMAL')

test_covid_dir = os.path.join(test_dir, 'COVID')
test_normal_dir = os.path.join(test_dir, 'NORMAL')

#print(train_dir)

# %%
image_gen_train_aug = ImageDataGenerator(
                    rescale=1./255,
                    preprocessing_function=custom_preprocessing,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )
train_data_gen_aug = image_gen_train_aug.flow_from_directory(batch_size=batch_size, 
                                               directory=train_dir, #implementation/loading of our data 
                                               shuffle=True,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')

image_gen_val = ImageDataGenerator(rescale = 1./255, preprocessing_function = custom_preprocessing)
val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size, 
                                               directory=validation_dir, #implementation/loading of our data 
                                               shuffle=False,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')

image_gen_test = ImageDataGenerator(rescale = 1./255) #needed if load images using flow_from_directory()
test_data_gen = image_gen_test.flow_from_directory(batch_size=batch_size, 
                                               directory=test_dir, #implementation/loading of our data 
                                               shuffle=False,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')
# Out:
# Found 1600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
model = Sequential([
    Input(shape=(img_height, img_width, 3)),
    
    Conv2D(16, 3, padding='same', activation='relu'), #remark: still debate over ReLu -> BN (theoretical) / BN -> ReLu (in practice) [both used]
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.1), #dont 'kill' important features (in beginning most low levels features are learned)
    
    Conv2D(32, 3, padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    
    Conv2D(64, 3, padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.2), #somewhat more severe dropout
    
    Flatten(),
    Dense(512, activation='relu'), #in dense layers dropout of 0.5, in general more dropout at end bcs more prone to overfitting (more abstract features learned at end)
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 299, 299, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 299, 299, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 149, 149, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 149, 149, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 149, 149, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 149, 149, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 74, 74, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 74, 74, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 87616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    44,859,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,884,449 (171.22 MB)
#  Trainable params: 44,884,225 (171.22 MB)
#  Non-trainable params: 224 (896.00 B)

# %%
EPOCHS = 30

# %%
#choose loss function binary cross entropy
model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy', 'recall'])

# %%
history = model.fit(
    train_data_gen_aug,
    steps_per_epoch=train_data_gen_aug.samples // batch_size,
    epochs=30,
    validation_data=val_data_gen,
    validation_steps=val_data_gen.samples // batch_size,
    verbose=1
)
# Out:
# /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 87s 7s/step - accuracy: 0.6194 - loss: 20.8446 - recall: 0.5975 - val_accuracy: 0.5130 - val_loss: 4.6865 - val_recall: 0.0109
# Epoch 2/30
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1:12 7s/step - accuracy: 0.6562 - loss: 4.1326 - recall: 0.6176
# /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6562 - loss: 4.1326 - recall: 0.6176 - val_accuracy: 0.5130 - val_loss: 5.5881 - val_recall: 0.0054
# Epoch 3/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 85s 7s/step - accuracy: 0.6910 - loss: 3.1918 - recall: 0.6547 - val_accuracy: 0.5130 - val_loss: 2.4545 - val_recall: 0.0217
# Epoch 4/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - accuracy: 0.7188 - loss: 1.1438 - recall: 0.6769 - val_accuracy: 0.5130 - val_loss: 2.3198 - val_recall: 0.0217
# Epoch 5/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 88s 7s/step - accuracy: 0.7067 - loss: 1.1109 - recall: 0.7174 - val_accuracy: 0.4505 - val_loss: 5.5908 - val_recall: 0.1467
# Epoch 6/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.7188 - loss: 0.7644 - recall: 0.7692 - val_accuracy: 0.4401 - val_loss: 7.3038 - val_recall: 0.1413
# Epoch 7/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 84s 7s/step - accuracy: 0.6953 - loss: 0.6648 - recall: 0.7457 - val_accuracy: 0.4974 - val_loss: 35.2538 - val_recall: 0.0054
# Epoch 8/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - accuracy: 0.6328 - loss: 0.6592 - recall: 0.4167 - val_accuracy: 0.5000 - val_loss: 37.6770 - val_recall: 0.0054
# Epoch 9/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 84s 7s/step - accuracy: 0.7207 - loss: 0.6200 - recall: 0.5800 - val_accuracy: 0.5208 - val_loss: 59.8896 - val_recall: 0.0000e+00
# Epoch 10/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 260ms/step - accuracy: 0.6797 - loss: 0.6393 - recall: 0.6667 - val_accuracy: 0.5208 - val_loss: 61.2732 - val_recall: 0.0000e+00
# Epoch 11/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 89s 7s/step - accuracy: 0.7245 - loss: 0.5300 - recall: 0.7265 - val_accuracy: 0.5208 - val_loss: 73.4863 - val_recall: 0.0000e+00
# Epoch 12/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.6953 - loss: 0.6064 - recall: 0.5634 - val_accuracy: 0.5208 - val_loss: 74.2107 - val_recall: 0.0000e+00
# Epoch 13/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 96s 8s/step - accuracy: 0.7288 - loss: 0.5379 - recall: 0.7318 - val_accuracy: 0.5208 - val_loss: 81.4824 - val_recall: 0.0000e+00
# Epoch 14/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6797 - loss: 0.5123 - recall: 0.6522 - val_accuracy: 0.5208 - val_loss: 81.9848 - val_recall: 0.0000e+00
# Epoch 15/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 85s 7s/step - accuracy: 0.7429 - loss: 0.5563 - recall: 0.7338 - val_accuracy: 0.5208 - val_loss: 86.0954 - val_recall: 0.0000e+00
# Epoch 16/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - accuracy: 0.7109 - loss: 0.5117 - recall: 0.6765 - val_accuracy: 0.5208 - val_loss: 86.2941 - val_recall: 0.0000e+00
# Epoch 17/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 87s 7s/step - accuracy: 0.7338 - loss: 0.5373 - recall: 0.7465 - val_accuracy: 0.5208 - val_loss: 90.2514 - val_recall: 0.0000e+00
# Epoch 18/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 297ms/step - accuracy: 0.7969 - loss: 0.5590 - recall: 0.8103 - val_accuracy: 0.5208 - val_loss: 90.4449 - val_recall: 0.0000e+00
# Epoch 19/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 87s 7s/step - accuracy: 0.7461 - loss: 0.5157 - recall: 0.7244 - val_accuracy: 0.5208 - val_loss: 91.4317 - val_recall: 0.0000e+00
# Epoch 20/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 339ms/step - accuracy: 0.8359 - loss: 0.4515 - recall: 0.8788 - val_accuracy: 0.5208 - val_loss: 91.3861 - val_recall: 0.0000e+00
# Epoch 21/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 94s 8s/step - accuracy: 0.7638 - loss: 0.4856 - recall: 0.7658 - val_accuracy: 0.5208 - val_loss: 89.2882 - val_recall: 0.0000e+00
# Epoch 22/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 299ms/step - accuracy: 0.7969 - loss: 0.4287 - recall: 0.7971 - val_accuracy: 0.5208 - val_loss: 89.0748 - val_recall: 0.0000e+00
# Epoch 23/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 88s 7s/step - accuracy: 0.7628 - loss: 0.4801 - recall: 0.7462 - val_accuracy: 0.5208 - val_loss: 86.0446 - val_recall: 0.0000e+00
# Epoch 24/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - accuracy: 0.8203 - loss: 0.4441 - recall: 0.8254 - val_accuracy: 0.5208 - val_loss: 85.6750 - val_recall: 0.0000e+00
# Epoch 25/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 90s 7s/step - accuracy: 0.7527 - loss: 0.4838 - recall: 0.7668 - val_accuracy: 0.5208 - val_loss: 81.9434 - val_recall: 0.0000e+00
# Epoch 26/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.7422 - loss: 0.5902 - recall: 0.7500 - val_accuracy: 0.5208 - val_loss: 81.6767 - val_recall: 0.0000e+00
# Epoch 27/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 86s 7s/step - accuracy: 0.7436 - loss: 0.5144 - recall: 0.7163 - val_accuracy: 0.5208 - val_loss: 74.0286 - val_recall: 0.0000e+00
# Epoch 28/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 276ms/step - accuracy: 0.7656 - loss: 0.4603 - recall: 0.7143 - val_accuracy: 0.5208 - val_loss: 73.3691 - val_recall: 0.0000e+00
# Epoch 29/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 89s 7s/step - accuracy: 0.7629 - loss: 0.4851 - recall: 0.7363 - val_accuracy: 0.5208 - val_loss: 64.5670 - val_recall: 0.0000e+00
# Epoch 30/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - accuracy: 0.7500 - loss: 0.5234 - recall: 0.7808 - val_accuracy: 0.5208 - val_loss: 63.9510 - val_recall: 0.0000e+00

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
