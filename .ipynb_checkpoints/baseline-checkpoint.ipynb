# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, Input, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import numpy as np
import matplotlib.pyplot as plt
import pathlib

import functions_ai

# %%
#print(os.getcwd())

# %% [markdown]
# ## 1) Setup

# %%
metrics = [
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc')] #verschillende metrics vergelijken

# Set random seed
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 2) Build initial model

# %%
custom_preprocessing = functions_ai.custom_preprocessing
batch_size = 128
img_height = img_width = 299

#set the paths/directories
path = pathlib.Path('covid xray')
train_dir = os.path.join(path, 'train') #just gives the path 
validation_dir = os.path.join(path, 'val')
test_dir = os.path.join(path, 'test')

train_covid_dir = os.path.join(train_dir, 'COVID')
train_normal_dir = os.path.join(train_dir, 'NORMAL')

validation_covid_dir = os.path.join(validation_dir, 'COVID')
validation_normal_dir = os.path.join(validation_dir, 'NORMAL')

test_covid_dir = os.path.join(test_dir, 'COVID')
test_normal_dir = os.path.join(test_dir, 'NORMAL')

#print(train_dir)

# %%
image_gen_train_aug = ImageDataGenerator(
                    rescale=1./255,
                    preprocessing_function=custom_preprocessing,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )
train_data_gen_aug = image_gen_train_aug.flow_from_directory(batch_size=batch_size, 
                                               directory=train_dir, #implementation/loading of our data 
                                               shuffle=True,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')

image_gen_val = ImageDataGenerator(rescale = 1./255, preprocessing_function = custom_preprocessing)
val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size, 
                                               directory=validation_dir, #implementation/loading of our data 
                                               shuffle=False,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')

image_gen_test = ImageDataGenerator(rescale = 1./255) #needed if load images using flow_from_directory()
test_data_gen = image_gen_test.flow_from_directory(batch_size=batch_size, 
                                               directory=test_dir, #implementation/loading of our data 
                                               shuffle=False,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')
# Out:
# Found 1600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
model = Sequential([
    Input(shape=(img_height, img_width, 3)),
    
    Conv2D(16, 3, padding='same', activation='relu'), #remark: still debate over ReLu -> BN (theoretical) / BN -> ReLu (in practice) [both used]
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.1), #dont 'kill' important features (in beginning most low levels features are learned)
    
    Conv2D(32, 3, padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    
    Conv2D(64, 3, padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.2), #somewhat more severe dropout
    
    Flatten(),
    Dense(512, activation='relu'), #in dense layers dropout of 0.5, in general more dropout at end bcs more prone to overfitting (more abstract features learned at end)
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 299, 299, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 299, 299, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 149, 149, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 149, 149, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 149, 149, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 149, 149, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 74, 74, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 74, 74, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 87616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    44,859,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,884,449 (171.22 MB)
#  Trainable params: 44,884,225 (171.22 MB)
#  Non-trainable params: 224 (896.00 B)

# %% [markdown]
# ## 3) Train your model

# %%
EPOCHS = 30

# %%
#choose loss function binary cross entropy
model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(),metrics= metrics)

# %%
#Train your initial model on the COVID dataset for thirty epochs while HOLDING OUT the validation set to monitor its performance.

image_gen_train_aug2 = ImageDataGenerator(
                    rescale=1./255,
                    preprocessing_function=custom_preprocessing,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5, validation_split = 0.2 #validation split on training data 
                    )



# Define train and validation generators
train_data_gen_aug2 = image_gen_train_aug2.flow_from_directory(directory=train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training',  # ← this is important
    shuffle=True
)

val_data_gen2 = image_gen_train_aug2.flow_from_directory(directory=train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation',  # ← this gives you the hold-out validation set
    shuffle=False
)
# Out:
# Found 1280 images belonging to 2 classes.
# Found 320 images belonging to 2 classes.

# %%
history = model.fit(
    train_data_gen_aug2,
    steps_per_epoch=train_data_gen_aug2.samples // batch_size,
    validation_data=val_data_gen2,
    validation_steps=val_data_gen2.samples // batch_size,
    epochs=30,
    verbose=1
)
# Out:
# /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 98s 9s/step - accuracy: 0.5805 - auc: 0.6140 - loss: 14.1917 - precision: 0.5598 - recall: 0.5643 - val_accuracy: 0.6250 - val_auc: 0.5000 - val_loss: 6.9754 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 86s 8s/step - accuracy: 0.6292 - auc: 0.6539 - loss: 5.2032 - precision: 0.6431 - recall: 0.6296 - val_accuracy: 0.6211 - val_auc: 0.4969 - val_loss: 6.3227 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 87s 8s/step - accuracy: 0.6938 - auc: 0.7547 - loss: 1.4487 - precision: 0.6959 - recall: 0.6801 - val_accuracy: 0.6250 - val_auc: 0.4866 - val_loss: 5.0701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 82s 8s/step - accuracy: 0.6983 - auc: 0.7553 - loss: 1.0573 - precision: 0.6919 - recall: 0.6864 - val_accuracy: 0.6250 - val_auc: 0.5191 - val_loss: 4.9336 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 83s 8s/step - accuracy: 0.7016 - auc: 0.7785 - loss: 0.7261 - precision: 0.6836 - recall: 0.7402 - val_accuracy: 0.6250 - val_auc: 0.4806 - val_loss: 9.3295 - val_precision: 0.5000 - val_recall: 0.0417
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 85s 8s/step - accuracy: 0.7291 - auc: 0.7994 - loss: 0.6152 - precision: 0.7469 - recall: 0.6951 - val_accuracy: 0.6211 - val_auc: 0.4926 - val_loss: 15.6430 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 83s 8s/step - accuracy: 0.7160 - auc: 0.7989 - loss: 0.5773 - precision: 0.7021 - recall: 0.7440 - val_accuracy: 0.6211 - val_auc: 0.4938 - val_loss: 19.1071 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 85s 8s/step - accuracy: 0.7393 - auc: 0.8204 - loss: 0.5421 - precision: 0.7183 - recall: 0.7777 - val_accuracy: 0.6250 - val_auc: 0.5000 - val_loss: 22.3231 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 78s 8s/step - accuracy: 0.7480 - auc: 0.8327 - loss: 0.5133 - precision: 0.7219 - recall: 0.8213 - val_accuracy: 0.6250 - val_auc: 0.5000 - val_loss: 23.2770 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.7610 - auc: 0.8412 - loss: 0.5068 - precision: 0.7652 - recall: 0.7613 - val_accuracy: 0.6250 - val_auc: 0.5000 - val_loss: 22.2730 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.7622 - auc: 0.8444 - loss: 0.5141 - precision: 0.7242 - recall: 0.8197 - val_accuracy: 0.6250 - val_auc: 0.5000 - val_loss: 23.0968 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 75s 7s/step - accuracy: 0.7516 - auc: 0.8448 - loss: 0.4928 - precision: 0.7461 - recall: 0.7745 - val_accuracy: 0.6250 - val_auc: 0.5000 - val_loss: 23.3929 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.7351 - auc: 0.8081 - loss: 0.5449 - precision: 0.7256 - recall: 0.7701 - val_accuracy: 0.6250 - val_auc: 0.5052 - val_loss: 22.2936 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 78s 8s/step - accuracy: 0.7518 - auc: 0.8508 - loss: 0.4796 - precision: 0.7511 - recall: 0.7477 - val_accuracy: 0.6250 - val_auc: 0.4969 - val_loss: 22.4039 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7412 - auc: 0.8351 - loss: 0.5001 - precision: 0.7176 - recall: 0.7807 - val_accuracy: 0.6211 - val_auc: 0.4969 - val_loss: 20.4378 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.7485 - auc: 0.8394 - loss: 0.4936 - precision: 0.7323 - recall: 0.7784 - val_accuracy: 0.6250 - val_auc: 0.5000 - val_loss: 19.5186 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 81s 8s/step - accuracy: 0.7477 - auc: 0.8433 - loss: 0.4983 - precision: 0.7497 - recall: 0.7609 - val_accuracy: 0.6211 - val_auc: 0.4938 - val_loss: 19.7865 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7738 - auc: 0.8643 - loss: 0.4561 - precision: 0.7700 - recall: 0.7868 - val_accuracy: 0.6328 - val_auc: 0.5043 - val_loss: 17.4525 - val_precision: 1.0000 - val_recall: 0.0208
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7832 - auc: 0.8624 - loss: 0.4736 - precision: 0.7701 - recall: 0.8001 - val_accuracy: 0.6211 - val_auc: 0.4965 - val_loss: 15.3344 - val_precision: 0.4000 - val_recall: 0.0208
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 76s 7s/step - accuracy: 0.7838 - auc: 0.8733 - loss: 0.4498 - precision: 0.7641 - recall: 0.8219 - val_accuracy: 0.6133 - val_auc: 0.4896 - val_loss: 17.9379 - val_precision: 0.2000 - val_recall: 0.0104
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.7688 - auc: 0.8641 - loss: 0.4626 - precision: 0.7765 - recall: 0.7716 - val_accuracy: 0.5859 - val_auc: 0.4546 - val_loss: 14.3366 - val_precision: 0.1429 - val_recall: 0.0208
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 77s 8s/step - accuracy: 0.7845 - auc: 0.8597 - loss: 0.4732 - precision: 0.7683 - recall: 0.8138 - val_accuracy: 0.6094 - val_auc: 0.4958 - val_loss: 14.5281 - val_precision: 0.1667 - val_recall: 0.0104
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 82s 8s/step - accuracy: 0.7602 - auc: 0.8611 - loss: 0.4616 - precision: 0.7348 - recall: 0.8205 - val_accuracy: 0.6094 - val_auc: 0.4813 - val_loss: 14.9415 - val_precision: 0.2500 - val_recall: 0.0208
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.7932 - auc: 0.8758 - loss: 0.4415 - precision: 0.7844 - recall: 0.7965 - val_accuracy: 0.5625 - val_auc: 0.4744 - val_loss: 12.6941 - val_precision: 0.2333 - val_recall: 0.0729
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 77s 7s/step - accuracy: 0.7805 - auc: 0.8798 - loss: 0.4341 - precision: 0.7583 - recall: 0.8167 - val_accuracy: 0.4727 - val_auc: 0.3862 - val_loss: 12.3156 - val_precision: 0.1803 - val_recall: 0.1146
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 77s 8s/step - accuracy: 0.7837 - auc: 0.8727 - loss: 0.4421 - precision: 0.7488 - recall: 0.8402 - val_accuracy: 0.6133 - val_auc: 0.4866 - val_loss: 15.2010 - val_precision: 0.2000 - val_recall: 0.0104
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.7802 - auc: 0.8704 - loss: 0.4594 - precision: 0.7576 - recall: 0.8240 - val_accuracy: 0.6133 - val_auc: 0.4894 - val_loss: 16.2477 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 77s 8s/step - accuracy: 0.7983 - auc: 0.8810 - loss: 0.4346 - precision: 0.7945 - recall: 0.8121 - val_accuracy: 0.6055 - val_auc: 0.4847 - val_loss: 12.2836 - val_precision: 0.2222 - val_recall: 0.0208
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 78s 8s/step - accuracy: 0.7964 - auc: 0.8838 - loss: 0.4303 - precision: 0.7900 - recall: 0.8028 - val_accuracy: 0.6211 - val_auc: 0.4958 - val_loss: 14.4362 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 77s 8s/step - accuracy: 0.7672 - auc: 0.8724 - loss: 0.4307 - precision: 0.7551 - recall: 0.7979 - val_accuracy: 0.6289 - val_auc: 0.4996 - val_loss: 10.4458 - val_precision: 0.6000 - val_recall: 0.0312

# %%
# List of metrics to plot
metrics_to_plot = ['accuracy', 'precision', 'recall', 'auc']

plt.figure(figsize=(14, 10))

for i, metric in enumerate(metrics_to_plot):
    plt.subplot(2, 2, i + 1)
    plt.plot(history.history[metric], label=f'Train {metric}')
    plt.plot(history.history[f'val_{metric}'], label=f'Val {metric}')
    plt.title(f'{metric.capitalize()} over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4) Hyperparameter tuning

# %% [markdown]
# For experimenting we can use fewer epochs (eg 5) and only train the best configurations on all 30 epochs

# %% [markdown]
# ### Implement early stopping

# %% [markdown]
# ### parameter search to tune your model

# %%
def build_model(filters=(16, 32, 64), dropout1=0.1, dropout2=0.2, dropout3=0.5, learning_rate=0.001):
    model = Sequential([
        Input(shape=(img_height, img_width, 3)),

        Conv2D(filters[0], 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(),
        Dropout(dropout1),

        Conv2D(filters[1], 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(),

        Conv2D(filters[2], 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(),
        Dropout(dropout2),

        Flatten(),
        Dense(512, activation='relu'),
        Dropout(dropout3),
        Dense(1, activation='sigmoid')
    ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=[
            tf.keras.metrics.BinaryAccuracy(name='accuracy'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall'),
            tf.keras.metrics.AUC(name='auc')
        ]
    )
    return model

# %%
import itertools
import pandas as pd

# Define hyperparameter ranges
dropout1_list = [0.1, 0.3]
dropout2_list = [0.2, 0.4]
learning_rates = [0.001, 0.0005]
batch_sizes = [16, 32]
filters_list = [(16, 32, 64), (8, 16, 32)]

# To store results
results = []

# Loop over all combinations
for d1, d2, lr, bs, filt in itertools.product(dropout1_list, dropout2_list, learning_rates, batch_sizes, filters_list):
    print(f"\nTraining with d1={d1}, d2={d2}, lr={lr}, bs={bs}, filters={filt}")
    
    model = build_model(
        filters=filt,
        dropout1=d1,
        dropout2=d2,
        dropout3=0.5,
        learning_rate=lr
    )

    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    history = model.fit(
        train_data_gen_aug2,
        validation_data=val_data_gen2,
        epochs=30,
        batch_size=bs,
        callbacks=[early_stop],
        verbose=1)

    # Save last epoch metrics
    last_epoch = -1
    results.append({
    'dropout1': d1,
    'dropout2': d2,
    'dropout3': 0.5,
    'learning_rate': lr,
    'batch_size': bs,
    'filters': filt,
    'val_accuracy': history.history['val_accuracy'][last_epoch],
    'val_precision': history.history['val_precision'][last_epoch],
    'val_recall': history.history['val_recall'][last_epoch],
    'val_auc': history.history['val_auc'][last_epoch]
})


# Save to CSV
df = pd.DataFrame(results)
df.to_csv("grid_search_hyperparams_results.csv", index=False)
# Out:
# Training with d1=0.1, d2=0.2, lr=0.001, bs=16, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 89s 8s/step - accuracy: 0.5637 - auc: 0.5745 - loss: 15.9134 - precision: 0.5604 - recall: 0.5801 - val_accuracy: 0.5625 - val_auc: 0.5735 - val_loss: 1.5878 - val_precision: 0.6786 - val_recall: 0.2375
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 81s 8s/step - accuracy: 0.6550 - auc: 0.6849 - loss: 4.1168 - precision: 0.6709 - recall: 0.5957 - val_accuracy: 0.6125 - val_auc: 0.6571 - val_loss: 3.1131 - val_precision: 0.6200 - val_recall: 0.5813
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7071 - auc: 0.7689 - loss: 1.5728 - precision: 0.6997 - recall: 0.7226 - val_accuracy: 0.5375 - val_auc: 0.5563 - val_loss: 6.3580 - val_precision: 0.5326 - val_recall: 0.6125
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 76s 7s/step - accuracy: 0.6472 - auc: 0.7122 - loss: 0.8070 - precision: 0.6820 - recall: 0.6279 - val_accuracy: 0.5063 - val_auc: 0.5143 - val_loss: 6.7514 - val_precision: 0.5065 - val_recall: 0.4875
#
# Training with d1=0.1, d2=0.2, lr=0.001, bs=16, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 62s 6s/step - accuracy: 0.5554 - auc: 0.5678 - loss: 21.6497 - precision: 0.5605 - recall: 0.4841 - val_accuracy: 0.5094 - val_auc: 0.7526 - val_loss: 0.9464 - val_precision: 0.7143 - val_recall: 0.0312
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 89s 9s/step - accuracy: 0.6147 - auc: 0.6467 - loss: 1.4045 - precision: 0.6117 - recall: 0.6888 - val_accuracy: 0.5437 - val_auc: 0.5494 - val_loss: 0.9331 - val_precision: 0.5412 - val_recall: 0.5750
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 92s 9s/step - accuracy: 0.6859 - auc: 0.7605 - loss: 0.6140 - precision: 0.7263 - recall: 0.6351 - val_accuracy: 0.5344 - val_auc: 0.5058 - val_loss: 2.1028 - val_precision: 0.5211 - val_recall: 0.8500
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 84s 8s/step - accuracy: 0.7199 - auc: 0.7918 - loss: 0.5544 - precision: 0.7038 - recall: 0.7180 - val_accuracy: 0.5250 - val_auc: 0.5285 - val_loss: 3.9421 - val_precision: 0.5172 - val_recall: 0.7500
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 85s 8s/step - accuracy: 0.7247 - auc: 0.7752 - loss: 0.6064 - precision: 0.7108 - recall: 0.7410 - val_accuracy: 0.4156 - val_auc: 0.4338 - val_loss: 9.0362 - val_precision: 0.3953 - val_recall: 0.3187
#
# Training with d1=0.3, d2=0.4, lr=0.0005, bs=32, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 6s/step - accuracy: 0.5799 - auc: 0.5816 - loss: 6.5174 - precision: 0.5638 - recall: 0.5535 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 7.7836 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 60s 6s/step - accuracy: 0.6386 - auc: 0.6992 - loss: 2.2793 - precision: 0.6927 - recall: 0.5588 - val_accuracy: 0.5000 - val_auc: 0.4754 - val_loss: 4.4455 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 63s 6s/step - accuracy: 0.6838 - auc: 0.7495 - loss: 0.9492 - precision: 0.7160 - recall: 0.6394 - val_accuracy: 0.4906 - val_auc: 0.4706 - val_loss: 3.5790 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 62s 6s/step - accuracy: 0.7405 - auc: 0.8002 - loss: 0.6011 - precision: 0.7397 - recall: 0.7468 - val_accuracy: 0.5000 - val_auc: 0.4786 - val_loss: 4.0279 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 59s 6s/step - accuracy: 0.7313 - auc: 0.7909 - loss: 0.5768 - precision: 0.7132 - recall: 0.8050 - val_accuracy: 0.5063 - val_auc: 0.5265 - val_loss: 3.3784 - val_precision: 0.6250 - val_recall: 0.0312
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.7436 - auc: 0.8120 - loss: 0.5309 - precision: 0.7138 - recall: 0.8162 - val_accuracy: 0.4969 - val_auc: 0.5336 - val_loss: 3.2801 - val_precision: 0.4286 - val_recall: 0.0188
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - accuracy: 0.7253 - auc: 0.8112 - loss: 0.5347 - precision: 0.6894 - recall: 0.8222 - val_accuracy: 0.5063 - val_auc: 0.5975 - val_loss: 3.2047 - val_precision: 0.6000 - val_recall: 0.0375
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 63s 6s/step - accuracy: 0.7224 - auc: 0.7953 - loss: 0.5581 - precision: 0.7072 - recall: 0.7379 - val_accuracy: 0.5094 - val_auc: 0.5860 - val_loss: 3.2858 - val_precision: 0.5652 - val_recall: 0.0812
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 60s 6s/step - accuracy: 0.7567 - auc: 0.8390 - loss: 0.4959 - precision: 0.7451 - recall: 0.7737 - val_accuracy: 0.5031 - val_auc: 0.5889 - val_loss: 3.7772 - val_precision: 0.5263 - val_recall: 0.0625
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 59s 6s/step - accuracy: 0.7442 - auc: 0.8233 - loss: 0.5359 - precision: 0.7269 - recall: 0.7608 - val_accuracy: 0.5625 - val_auc: 0.6804 - val_loss: 3.3324 - val_precision: 0.8571 - val_recall: 0.1500

# %% [markdown]
# ## 5) final baseline model (with validation set)

# %%
model_final = build_model(
        filters=(8, 16, 32),
        dropout1=0.1,
        dropout2=0.2,
        dropout3=0.5,
        learning_rate= 0.0005
    )

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history_final = model_final.fit(
        train_data_gen_aug,
        validation_data=val_data_gen,
        epochs=30,
        batch_size=32,
        callbacks=[early_stop],
        verbose=1)
# Out:
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 73s 5s/step - accuracy: 0.5903 - auc: 0.6216 - loss: 7.5054 - precision: 0.5911 - recall: 0.6185 - val_accuracy: 0.4925 - val_auc: 0.3811 - val_loss: 9.7894 - val_precision: 0.4960 - val_recall: 0.9400
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 64s 5s/step - accuracy: 0.6507 - auc: 0.7056 - loss: 0.7167 - precision: 0.6506 - recall: 0.6880 - val_accuracy: 0.4000 - val_auc: 0.3205 - val_loss: 7.6444 - val_precision: 0.4379 - val_recall: 0.7050
# Epoch 3/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.6891 - auc: 0.7936 - loss: 0.5794 - precision: 0.7561 - recall: 0.5577 - val_accuracy: 0.3150 - val_auc: 0.3101 - val_loss: 4.9290 - val_precision: 0.3432 - val_recall: 0.4050
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.7328 - auc: 0.8132 - loss: 0.5477 - precision: 0.7456 - recall: 0.7098 - val_accuracy: 0.3650 - val_auc: 0.3759 - val_loss: 3.5998 - val_precision: 0.3313 - val_recall: 0.2650
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.7341 - auc: 0.8156 - loss: 0.5302 - precision: 0.7256 - recall: 0.7421 - val_accuracy: 0.4350 - val_auc: 0.4753 - val_loss: 3.1502 - val_precision: 0.3617 - val_recall: 0.1700
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.7571 - auc: 0.8474 - loss: 0.4818 - precision: 0.7681 - recall: 0.7405 - val_accuracy: 0.4800 - val_auc: 0.5341 - val_loss: 3.8647 - val_precision: 0.4259 - val_recall: 0.1150
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step - accuracy: 0.7473 - auc: 0.8219 - loss: 0.5250 - precision: 0.7387 - recall: 0.7622 - val_accuracy: 0.5000 - val_auc: 0.5134 - val_loss: 5.1166 - val_precision: 0.5000 - val_recall: 0.0800
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 69s 5s/step - accuracy: 0.7769 - auc: 0.8597 - loss: 0.4676 - precision: 0.8152 - recall: 0.7237 - val_accuracy: 0.4825 - val_auc: 0.4976 - val_loss: 6.7437 - val_precision: 0.2941 - val_recall: 0.0250
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 65s 5s/step - accuracy: 0.7630 - auc: 0.8506 - loss: 0.4744 - precision: 0.7894 - recall: 0.7238 - val_accuracy: 0.4925 - val_auc: 0.4843 - val_loss: 8.2643 - val_precision: 0.3333 - val_recall: 0.0150
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 64s 5s/step - accuracy: 0.7751 - auc: 0.8546 - loss: 0.4690 - precision: 0.7999 - recall: 0.7312 - val_accuracy: 0.5000 - val_auc: 0.4802 - val_loss: 9.3153 - val_precision: 0.5000 - val_recall: 0.0100

# %%
# List of metrics to plot
metrics_to_plot = ['accuracy', 'precision', 'recall', 'auc']

plt.figure(figsize=(14, 10))

for i, metric in enumerate(metrics_to_plot):
    plt.subplot(2, 2, i + 1)
    plt.plot(history_final.history[metric], label=f'Train {metric}')
    plt.plot(history_final.history[f'val_{metric}'], label=f'Val {metric}')
    plt.title(f'{metric.capitalize()} over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Alternative optimizer (RMSprop instead of Adam)
