# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, Input, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import os
import numpy as np
import matplotlib.pyplot as plt
import pathlib

import functions_ai

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 1) Setup

# %%
metrics = [
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc')] #verschillende metrics vergelijken

# Set random seed
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 2) Build initial model

# %%
custom_preprocessing = functions_ai.custom_preprocessing
batch_size = 128
img_height = img_width = 299

#set the paths/directories
path = pathlib.Path('covid xray')
train_dir = os.path.join(path, 'train') 
validation_dir = os.path.join(path, 'val')
test_dir = os.path.join(path, 'test')

train_covid_dir = os.path.join(train_dir, 'COVID')
train_normal_dir = os.path.join(train_dir, 'NORMAL')

validation_covid_dir = os.path.join(validation_dir, 'COVID')
validation_normal_dir = os.path.join(validation_dir, 'NORMAL')

test_covid_dir = os.path.join(test_dir, 'COVID')
test_normal_dir = os.path.join(test_dir, 'NORMAL')

#print(train_dir)

# %%
image_gen_train_aug = ImageDataGenerator(
                    rescale=1./255,
                    preprocessing_function=custom_preprocessing,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )
train_data_gen_aug = image_gen_train_aug.flow_from_directory(batch_size=batch_size, 
                                               directory=train_dir, #implementation/loading of our data 
                                               shuffle=True,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')

image_gen_val = ImageDataGenerator(rescale = 1./255, preprocessing_function = custom_preprocessing)
val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size, 
                                               directory=validation_dir, #implementation/loading of our data 
                                               shuffle=False,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')

image_gen_test = ImageDataGenerator(rescale = 1./255) #needed if load images using flow_from_directory()
test_data_gen = image_gen_test.flow_from_directory(batch_size=batch_size, 
                                               directory=test_dir, #implementation/loading of our data 
                                               shuffle=False,
                                               target_size=(img_height, img_width),  #pre-processing (together with scaler in ImageDataGenerator
                                                class_mode='binary')
# Out:
# Found 1600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
model = Sequential([
    Input(shape=(img_height, img_width, 3)),
    
    Conv2D(16, 3, padding='same', activation='relu'), #remark: still debate over ReLu -> BN (theoretical) / BN -> ReLu (in practice) [both used]
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.1), #dont 'kill' important features (in beginning most low levels features are learned)
    
    Conv2D(32, 3, padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    
    Conv2D(64, 3, padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.2), #somewhat more severe dropout
    
    Flatten(),
    Dense(512, activation='relu'), #in dense layers dropout of 0.5, in general more dropout at end bcs more prone to overfitting (more abstract features learned at end)
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 299, 299, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 299, 299, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 149, 149, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 149, 149, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 149, 149, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 149, 149, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 74, 74, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 74, 74, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 87616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    44,859,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,884,449 (171.22 MB)
#  Trainable params: 44,884,225 (171.22 MB)
#  Non-trainable params: 224 (896.00 B)

# %% [markdown]
# ## 3) Train your model

# %%
#choose loss function binary cross entropy
model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(),metrics= metrics)

# %%
history = model.fit(
    train_data_gen_aug,
    validation_data=val_data_gen, #?????
    steps_per_epoch=train_data_gen_aug.samples // batch_size,
    epochs=30,
    verbose=1
)
# Out:
# /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 89s 7s/step - accuracy: 0.5956 - auc: 0.6225 - loss: 27.0018 - precision: 0.6115 - recall: 0.5779 - val_accuracy: 0.4375 - val_auc: 0.4446 - val_loss: 0.9479 - val_precision: 0.4481 - val_recall: 0.5400
# Epoch 2/30
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1:11 6s/step - accuracy: 0.6250 - auc: 0.6855 - loss: 1.9416 - precision: 0.6441 - recall: 0.5846
# /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - accuracy: 0.6250 - auc: 0.6855 - loss: 1.9416 - precision: 0.6441 - recall: 0.5846 - val_accuracy: 0.4350 - val_auc: 0.4342 - val_loss: 1.0162 - val_precision: 0.4484 - val_recall: 0.5650
# Epoch 3/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 81s 7s/step - accuracy: 0.6595 - auc: 0.7091 - loss: 1.6799 - precision: 0.6539 - recall: 0.6636 - val_accuracy: 0.5125 - val_auc: 0.6254 - val_loss: 2.4740 - val_precision: 0.6667 - val_recall: 0.0500
# Epoch 4/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.6172 - auc: 0.6808 - loss: 1.2884 - precision: 0.5181 - recall: 0.8269 - val_accuracy: 0.5175 - val_auc: 0.6016 - val_loss: 2.5218 - val_precision: 0.6667 - val_recall: 0.0700
# Epoch 5/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 87s 7s/step - accuracy: 0.6751 - auc: 0.7660 - loss: 0.7461 - precision: 0.6247 - recall: 0.8768 - val_accuracy: 0.4650 - val_auc: 0.4262 - val_loss: 7.4302 - val_precision: 0.4493 - val_recall: 0.3100
# Epoch 6/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - accuracy: 0.6250 - auc: 0.7538 - loss: 0.6174 - precision: 0.5349 - recall: 0.8519 - val_accuracy: 0.4525 - val_auc: 0.4279 - val_loss: 8.2089 - val_precision: 0.4336 - val_recall: 0.3100
# Epoch 7/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 86s 7s/step - accuracy: 0.6885 - auc: 0.7760 - loss: 0.5734 - precision: 0.6480 - recall: 0.8598 - val_accuracy: 0.4200 - val_auc: 0.4179 - val_loss: 16.2891 - val_precision: 0.3857 - val_recall: 0.2700
# Epoch 8/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - accuracy: 0.7109 - auc: 0.7832 - loss: 0.7194 - precision: 0.6538 - recall: 0.8361 - val_accuracy: 0.4175 - val_auc: 0.4188 - val_loss: 16.7835 - val_precision: 0.3796 - val_recall: 0.2600
# Epoch 9/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 85s 7s/step - accuracy: 0.7062 - auc: 0.8002 - loss: 0.5578 - precision: 0.6582 - recall: 0.8293 - val_accuracy: 0.4325 - val_auc: 0.4328 - val_loss: 20.8058 - val_precision: 0.3805 - val_recall: 0.2150
# Epoch 10/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 320ms/step - accuracy: 0.7656 - auc: 0.8599 - loss: 0.4654 - precision: 0.7467 - recall: 0.8358 - val_accuracy: 0.4325 - val_auc: 0.4354 - val_loss: 21.1027 - val_precision: 0.3805 - val_recall: 0.2150
# Epoch 11/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 89s 8s/step - accuracy: 0.7206 - auc: 0.8159 - loss: 0.5311 - precision: 0.6968 - recall: 0.7782 - val_accuracy: 0.4800 - val_auc: 0.4582 - val_loss: 24.2346 - val_precision: 0.4524 - val_recall: 0.1900
# Epoch 12/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step - accuracy: 0.7031 - auc: 0.7834 - loss: 0.5367 - precision: 0.7089 - recall: 0.7887 - val_accuracy: 0.4800 - val_auc: 0.4642 - val_loss: 24.4689 - val_precision: 0.4524 - val_recall: 0.1900
# Epoch 13/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 88s 7s/step - accuracy: 0.7115 - auc: 0.8099 - loss: 0.5361 - precision: 0.6808 - recall: 0.8325 - val_accuracy: 0.4975 - val_auc: 0.4885 - val_loss: 29.3362 - val_precision: 0.4894 - val_recall: 0.1150
# Epoch 14/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - accuracy: 0.6953 - auc: 0.7555 - loss: 0.5945 - precision: 0.6386 - recall: 0.8548 - val_accuracy: 0.5025 - val_auc: 0.4906 - val_loss: 29.7944 - val_precision: 0.5116 - val_recall: 0.1100
# Epoch 15/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 93s 8s/step - accuracy: 0.7218 - auc: 0.8126 - loss: 0.5340 - precision: 0.6812 - recall: 0.8240 - val_accuracy: 0.4875 - val_auc: 0.4924 - val_loss: 34.4862 - val_precision: 0.3810 - val_recall: 0.0400
# Epoch 16/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 357ms/step - accuracy: 0.7656 - auc: 0.8522 - loss: 0.4732 - precision: 0.8654 - recall: 0.6618 - val_accuracy: 0.4900 - val_auc: 0.4924 - val_loss: 34.8535 - val_precision: 0.4000 - val_recall: 0.0400
# Epoch 17/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 89s 7s/step - accuracy: 0.7171 - auc: 0.8020 - loss: 0.5365 - precision: 0.7586 - recall: 0.5873 - val_accuracy: 0.4950 - val_auc: 0.4925 - val_loss: 38.6574 - val_precision: 0.4375 - val_recall: 0.0350
# Epoch 18/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.7500 - auc: 0.8333 - loss: 0.4549 - precision: 0.8621 - recall: 0.6757 - val_accuracy: 0.4950 - val_auc: 0.4950 - val_loss: 39.0174 - val_precision: 0.4375 - val_recall: 0.0350
# Epoch 19/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 86s 7s/step - accuracy: 0.7361 - auc: 0.8502 - loss: 0.4802 - precision: 0.7910 - recall: 0.6567 - val_accuracy: 0.4975 - val_auc: 0.4854 - val_loss: 39.8150 - val_precision: 0.4706 - val_recall: 0.0400
# Epoch 20/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 317ms/step - accuracy: 0.7344 - auc: 0.8124 - loss: 0.5172 - precision: 0.7955 - recall: 0.5833 - val_accuracy: 0.4950 - val_auc: 0.4877 - val_loss: 39.7771 - val_precision: 0.4444 - val_recall: 0.0400
# Epoch 21/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 88s 7s/step - accuracy: 0.7138 - auc: 0.8175 - loss: 0.5258 - precision: 0.8379 - recall: 0.5421 - val_accuracy: 0.4950 - val_auc: 0.4949 - val_loss: 43.0307 - val_precision: 0.4375 - val_recall: 0.0350
# Epoch 22/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - accuracy: 0.7188 - auc: 0.8070 - loss: 0.4980 - precision: 0.8837 - recall: 0.5507 - val_accuracy: 0.4950 - val_auc: 0.4950 - val_loss: 43.3873 - val_precision: 0.4375 - val_recall: 0.0350
# Epoch 23/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 92s 7s/step - accuracy: 0.7212 - auc: 0.8156 - loss: 0.5242 - precision: 0.7747 - recall: 0.6023 - val_accuracy: 0.4900 - val_auc: 0.4924 - val_loss: 46.5521 - val_precision: 0.3333 - val_recall: 0.0200
# Epoch 24/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - accuracy: 0.8125 - auc: 0.9593 - loss: 0.3548 - precision: 0.9615 - recall: 0.6944 - val_accuracy: 0.4900 - val_auc: 0.4924 - val_loss: 46.7012 - val_precision: 0.3333 - val_recall: 0.0200
# Epoch 25/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 87s 7s/step - accuracy: 0.7142 - auc: 0.8243 - loss: 0.4997 - precision: 0.7383 - recall: 0.7016 - val_accuracy: 0.4950 - val_auc: 0.4950 - val_loss: 47.5330 - val_precision: 0.4375 - val_recall: 0.0350
# Epoch 26/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - accuracy: 0.7031 - auc: 0.7864 - loss: 0.5756 - precision: 0.6974 - recall: 0.7794 - val_accuracy: 0.4950 - val_auc: 0.4950 - val_loss: 47.6302 - val_precision: 0.4375 - val_recall: 0.0350
# Epoch 27/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 90s 7s/step - accuracy: 0.7480 - auc: 0.8381 - loss: 0.5013 - precision: 0.7161 - recall: 0.8151 - val_accuracy: 0.4975 - val_auc: 0.4950 - val_loss: 49.4655 - val_precision: 0.4667 - val_recall: 0.0350
# Epoch 28/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6875 - auc: 0.8112 - loss: 0.5045 - precision: 0.6705 - recall: 0.8429 - val_accuracy: 0.5000 - val_auc: 0.4950 - val_loss: 49.5438 - val_precision: 0.5000 - val_recall: 0.0350
# Epoch 29/30
#  5/12 ━━━━━━━━━━━━━━━━━━━━ 44s 6s/step - accuracy: 0.7273 - auc: 0.8318 - loss: 0.5148 - precision: 0.6922 - recall: 0.8503
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 history = model.fit(
#       2     train_data_gen_aug,
#       3     validation_data=val_data_gen,
#       4     steps_per_epoch=train_data_gen_aug.samples // batch_size,
#       5     epochs=30,
#       6     verbose=1
#       7 )
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /opt/anaconda3/envs/AI/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# List of metrics to plot
metrics_to_plot = ['accuracy', 'precision', 'recall', 'auc']

plt.figure(figsize=(14, 10))

for i, metric in enumerate(metrics_to_plot):
    plt.subplot(2, 2, i + 1)
    plt.plot(history.history[metric], label=f'Train {metric}')
    plt.plot(history.history[f'val_{metric}'], label=f'Val {metric}')
    plt.title(f'{metric.capitalize()} over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4) Hyperparameter tuning

# %% [markdown]
# ### Implement early stopping

# %% [markdown]
# ### parameter search to tune your model

# %%
def build_model(optimizer,filters=(16, 32, 64), dropout1=0.1, dropout2=0.2, dropout3=0.5, learning_rate=0.001):
    model = Sequential([
        Input(shape=(img_height, img_width, 3)),

        Conv2D(filters[0], 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(),
        Dropout(dropout1),

        Conv2D(filters[1], 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(),

        Conv2D(filters[2], 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(),
        Dropout(dropout2),

        Flatten(),
        Dense(512, activation='relu'),
        Dropout(dropout3),
        Dense(1, activation='sigmoid')
    ])

    # optimizer
    if opt == 'adam':
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif opt == 'rmsprop':
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)


    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=[
            tf.keras.metrics.BinaryAccuracy(name='accuracy'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall'),
            tf.keras.metrics.AUC(name='auc')
        ]
    )
    return model

# %%
import itertools
import pandas as pd

# Define hyperparameter ranges
dropout1_list = [0.1, 0.3]
dropout2_list = [0.2, 0.4]
learning_rates = [0.001, 0.0005]
filters_list = [(16, 32, 64), (8, 16, 32)]
optimizers = ['adam', 'rmsprop']

# To store results
results = []

# Loop over all combinations
for d1, d2, lr, opt, filt in itertools.product(dropout1_list, dropout2_list, learning_rates, optimizers, filters_list):
    print(f"\nTraining with d1={d1}, d2={d2}, lr={lr}, opt={opt}, filters={filt}")
    
    model = build_model(
        opt,
        filters=filt,
        dropout1=d1,
        dropout2=d2,
        dropout3=0.5,
        learning_rate=lr
    )

    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    history = model.fit(
        train_data_gen_aug,
        validation_data=val_data_gen ###?????????
        epochs=30,
        batch_size= batch_size,
        callbacks=[early_stop],
        verbose=1)

    # Save last epoch metrics
    last_epoch = -1
    results.append({
    'dropout1': d1,
    'dropout2': d2,
    'dropout3': 0.5,
    'learning_rate': lr,
    'batch_size': batch_size,
    'filters': filt,
    'optimizer': opt, 
    'val_accuracy': history.history['val_accuracy'][last_epoch],
    'val_precision': history.history['val_precision'][last_epoch],
    'val_recall': history.history['val_recall'][last_epoch],
    'val_auc': history.history['val_auc'][last_epoch]
})


# Save to CSV
df = pd.DataFrame(results)
df.to_csv("grid_search_hyperparams_results2.0.csv", index=False)
# Out:
# Training with d1=0.1, d2=0.2, lr=0.001, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 75s 7s/step - accuracy: 0.6023 - auc: 0.6216 - loss: 20.5829 - precision: 0.5998 - recall: 0.6080 - val_accuracy: 0.4938 - val_auc: 0.8741 - val_loss: 1.2568 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.5945 - auc: 0.6105 - loss: 3.0475 - precision: 0.5848 - recall: 0.7221 - val_accuracy: 0.7250 - val_auc: 0.7941 - val_loss: 0.7001 - val_precision: 0.6513 - val_recall: 0.9688
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.6722 - auc: 0.7468 - loss: 0.7539 - precision: 0.7147 - recall: 0.5963 - val_accuracy: 0.5562 - val_auc: 0.7913 - val_loss: 2.3293 - val_precision: 0.5298 - val_recall: 1.0000
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6853 - auc: 0.7390 - loss: 0.6114 - precision: 0.6794 - recall: 0.6911 - val_accuracy: 0.5281 - val_auc: 0.5597 - val_loss: 7.9977 - val_precision: 0.5145 - val_recall: 1.0000
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.7335 - auc: 0.7981 - loss: 0.5702 - precision: 0.7191 - recall: 0.7623 - val_accuracy: 0.5312 - val_auc: 0.5410 - val_loss: 13.4785 - val_precision: 0.5162 - val_recall: 0.9937
#
# Training with d1=0.1, d2=0.2, lr=0.001, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 57s 5s/step - accuracy: 0.5611 - auc: 0.5843 - loss: 12.6814 - precision: 0.5698 - recall: 0.5764 - val_accuracy: 0.5031 - val_auc: 0.6592 - val_loss: 0.8445 - val_precision: 0.5016 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.6563 - auc: 0.7172 - loss: 0.7835 - precision: 0.6641 - recall: 0.7105 - val_accuracy: 0.5500 - val_auc: 0.6979 - val_loss: 0.7054 - val_precision: 0.5263 - val_recall: 1.0000
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7019 - auc: 0.7765 - loss: 0.6179 - precision: 0.7252 - recall: 0.6825 - val_accuracy: 0.4688 - val_auc: 0.4633 - val_loss: 0.7491 - val_precision: 0.4779 - val_recall: 0.6750
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6929 - auc: 0.7500 - loss: 0.6257 - precision: 0.6827 - recall: 0.7311 - val_accuracy: 0.4031 - val_auc: 0.4323 - val_loss: 0.8128 - val_precision: 0.4188 - val_recall: 0.5000
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7619 - auc: 0.8364 - loss: 0.5185 - precision: 0.7629 - recall: 0.7682 - val_accuracy: 0.4313 - val_auc: 0.3466 - val_loss: 1.2578 - val_precision: 0.3226 - val_recall: 0.1250
#
# Training with d1=0.1, d2=0.2, lr=0.001, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 88s 7s/step - accuracy: 0.5476 - auc: 0.5775 - loss: 73.5221 - precision: 0.5639 - recall: 0.5309 - val_accuracy: 0.7500 - val_auc: 0.8276 - val_loss: 1.0638 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 78s 7s/step - accuracy: 0.6574 - auc: 0.7087 - loss: 2.7853 - precision: 0.6347 - recall: 0.6981 - val_accuracy: 0.7531 - val_auc: 0.8557 - val_loss: 0.6546 - val_precision: 0.7516 - val_recall: 0.7563
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6533 - auc: 0.7010 - loss: 1.8089 - precision: 0.6759 - recall: 0.6479 - val_accuracy: 0.5281 - val_auc: 0.6052 - val_loss: 1.9255 - val_precision: 0.6000 - val_recall: 0.1688
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6966 - auc: 0.7301 - loss: 0.9758 - precision: 0.6851 - recall: 0.7533 - val_accuracy: 0.5063 - val_auc: 0.5536 - val_loss: 3.7572 - val_precision: 0.5556 - val_recall: 0.0625
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6711 - auc: 0.7349 - loss: 1.0558 - precision: 0.6638 - recall: 0.6899 - val_accuracy: 0.6500 - val_auc: 0.8136 - val_loss: 1.5844 - val_precision: 1.0000 - val_recall: 0.3000
#
# Training with d1=0.1, d2=0.2, lr=0.001, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.5952 - auc: 0.6090 - loss: 55.3779 - precision: 0.5937 - recall: 0.6075 - val_accuracy: 0.6094 - val_auc: 0.6982 - val_loss: 1.1357 - val_precision: 0.5614 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 46s 5s/step - accuracy: 0.6513 - auc: 0.7322 - loss: 0.8506 - precision: 0.6263 - recall: 0.7760 - val_accuracy: 0.4844 - val_auc: 0.4821 - val_loss: 1.6985 - val_precision: 0.4809 - val_recall: 0.3938
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7152 - auc: 0.7818 - loss: 0.7165 - precision: 0.7034 - recall: 0.7580 - val_accuracy: 0.4969 - val_auc: 0.4781 - val_loss: 10.6564 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7007 - auc: 0.7568 - loss: 0.6941 - precision: 0.6743 - recall: 0.7913 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 21.2096 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.1, d2=0.2, lr=0.0005, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 73s 7s/step - accuracy: 0.5961 - auc: 0.6078 - loss: 8.3967 - precision: 0.5826 - recall: 0.5999 - val_accuracy: 0.4812 - val_auc: 0.5229 - val_loss: 0.8726 - val_precision: 0.4750 - val_recall: 0.3562
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6578 - auc: 0.6909 - loss: 4.3642 - precision: 0.6849 - recall: 0.5784 - val_accuracy: 0.4187 - val_auc: 0.4743 - val_loss: 1.0824 - val_precision: 0.2500 - val_recall: 0.0812
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6535 - auc: 0.7204 - loss: 1.2149 - precision: 0.6348 - recall: 0.7229 - val_accuracy: 0.6313 - val_auc: 0.5696 - val_loss: 1.1787 - val_precision: 0.5833 - val_recall: 0.9187
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7177 - auc: 0.7684 - loss: 0.6193 - precision: 0.7007 - recall: 0.7818 - val_accuracy: 0.6187 - val_auc: 0.5994 - val_loss: 2.1359 - val_precision: 0.5704 - val_recall: 0.9625
#
# Training with d1=0.1, d2=0.2, lr=0.0005, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 53s 5s/step - accuracy: 0.5628 - auc: 0.5964 - loss: 8.6266 - precision: 0.5824 - recall: 0.5546 - val_accuracy: 0.6938 - val_auc: 0.8560 - val_loss: 0.7638 - val_precision: 0.6202 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6478 - auc: 0.7179 - loss: 0.8126 - precision: 0.6480 - recall: 0.7407 - val_accuracy: 0.7188 - val_auc: 0.8444 - val_loss: 0.7229 - val_precision: 0.6423 - val_recall: 0.9875
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6707 - auc: 0.7445 - loss: 0.6207 - precision: 0.6277 - recall: 0.8659 - val_accuracy: 0.8031 - val_auc: 0.8767 - val_loss: 0.5103 - val_precision: 0.8129 - val_recall: 0.7875
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6873 - auc: 0.7815 - loss: 0.5675 - precision: 0.6732 - recall: 0.7805 - val_accuracy: 0.7594 - val_auc: 0.8778 - val_loss: 0.5388 - val_precision: 0.8120 - val_recall: 0.6750
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7223 - auc: 0.8263 - loss: 0.5079 - precision: 0.6805 - recall: 0.8346 - val_accuracy: 0.7812 - val_auc: 0.8983 - val_loss: 0.5409 - val_precision: 0.8571 - val_recall: 0.6750
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7052 - auc: 0.7861 - loss: 0.5667 - precision: 0.6761 - recall: 0.8100 - val_accuracy: 0.8125 - val_auc: 0.9197 - val_loss: 0.5100 - val_precision: 0.8846 - val_recall: 0.7188
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7284 - auc: 0.8254 - loss: 0.5250 - precision: 0.6865 - recall: 0.8249 - val_accuracy: 0.8281 - val_auc: 0.9332 - val_loss: 0.5258 - val_precision: 0.9268 - val_recall: 0.7125
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7203 - auc: 0.8043 - loss: 0.5501 - precision: 0.6905 - recall: 0.8089 - val_accuracy: 0.8406 - val_auc: 0.9354 - val_loss: 0.5240 - val_precision: 0.9291 - val_recall: 0.7375
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7115 - auc: 0.8094 - loss: 0.5244 - precision: 0.6847 - recall: 0.7629 - val_accuracy: 0.8156 - val_auc: 0.9315 - val_loss: 0.6818 - val_precision: 0.9550 - val_recall: 0.6625
#
# Training with d1=0.1, d2=0.2, lr=0.0005, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - accuracy: 0.5818 - auc: 0.6070 - loss: 30.6392 - precision: 0.5847 - recall: 0.6256 - val_accuracy: 0.7937 - val_auc: 0.8678 - val_loss: 0.5212 - val_precision: 0.7398 - val_recall: 0.9062
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.6631 - auc: 0.7258 - loss: 1.7303 - precision: 0.6724 - recall: 0.6659 - val_accuracy: 0.6469 - val_auc: 0.8471 - val_loss: 0.8030 - val_precision: 0.5887 - val_recall: 0.9750
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7187 - auc: 0.7842 - loss: 0.7210 - precision: 0.7477 - recall: 0.6609 - val_accuracy: 0.7312 - val_auc: 0.7805 - val_loss: 0.7368 - val_precision: 0.7312 - val_recall: 0.7312
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7041 - auc: 0.7713 - loss: 0.6337 - precision: 0.7241 - recall: 0.6411 - val_accuracy: 0.6500 - val_auc: 0.7639 - val_loss: 1.0904 - val_precision: 0.7500 - val_recall: 0.4500
#
# Training with d1=0.1, d2=0.2, lr=0.0005, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.5846 - auc: 0.6020 - loss: 29.7812 - precision: 0.5996 - recall: 0.5631 - val_accuracy: 0.5250 - val_auc: 0.9204 - val_loss: 0.7593 - val_precision: 0.5128 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6873 - auc: 0.7716 - loss: 0.6084 - precision: 0.6800 - recall: 0.7336 - val_accuracy: 0.4688 - val_auc: 0.4797 - val_loss: 1.3474 - val_precision: 0.4468 - val_recall: 0.2625
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6868 - auc: 0.7647 - loss: 0.6292 - precision: 0.6891 - recall: 0.6936 - val_accuracy: 0.5000 - val_auc: 0.4969 - val_loss: 9.6399 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6995 - auc: 0.7839 - loss: 0.5889 - precision: 0.6799 - recall: 0.7650 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 15.5577 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.1, d2=0.4, lr=0.001, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 76s 7s/step - accuracy: 0.5735 - auc: 0.5813 - loss: 27.9315 - precision: 0.5907 - recall: 0.5357 - val_accuracy: 0.4969 - val_auc: 0.2945 - val_loss: 1.4358 - val_precision: 0.4983 - val_recall: 0.9187
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6588 - auc: 0.7189 - loss: 1.8575 - precision: 0.6380 - recall: 0.7257 - val_accuracy: 0.5000 - val_auc: 0.3156 - val_loss: 3.9909 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.6541 - auc: 0.7278 - loss: 0.7554 - precision: 0.6246 - recall: 0.8102 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 22.9078 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.6447 - auc: 0.7392 - loss: 0.6458 - precision: 0.5904 - recall: 0.9108 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 30.6916 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.1, d2=0.4, lr=0.001, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 51s 5s/step - accuracy: 0.5936 - auc: 0.6061 - loss: 15.7484 - precision: 0.6156 - recall: 0.5663 - val_accuracy: 0.5000 - val_auc: 0.6872 - val_loss: 2.9570 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6389 - auc: 0.7067 - loss: 0.8717 - precision: 0.5918 - recall: 0.8396 - val_accuracy: 0.7812 - val_auc: 0.8462 - val_loss: 0.5210 - val_precision: 0.8041 - val_recall: 0.7437
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6615 - auc: 0.7240 - loss: 0.6076 - precision: 0.6158 - recall: 0.8554 - val_accuracy: 0.7875 - val_auc: 0.8322 - val_loss: 0.6427 - val_precision: 0.7212 - val_recall: 0.9375
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6790 - auc: 0.7600 - loss: 0.5998 - precision: 0.6398 - recall: 0.8569 - val_accuracy: 0.7688 - val_auc: 0.8079 - val_loss: 1.2938 - val_precision: 0.6853 - val_recall: 0.9937
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6689 - auc: 0.7738 - loss: 0.5650 - precision: 0.6258 - recall: 0.8587 - val_accuracy: 0.7094 - val_auc: 0.8132 - val_loss: 2.6329 - val_precision: 0.6324 - val_recall: 1.0000
#
# Training with d1=0.1, d2=0.4, lr=0.001, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 75s 7s/step - accuracy: 0.5262 - auc: 0.5386 - loss: 60.4196 - precision: 0.5301 - recall: 0.4868 - val_accuracy: 0.5031 - val_auc: 0.4908 - val_loss: 6.6142 - val_precision: 0.5556 - val_recall: 0.0312
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6855 - auc: 0.7422 - loss: 3.0371 - precision: 0.6922 - recall: 0.6613 - val_accuracy: 0.5125 - val_auc: 0.5446 - val_loss: 4.2375 - val_precision: 0.7500 - val_recall: 0.0375
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step - accuracy: 0.6409 - auc: 0.7011 - loss: 1.5358 - precision: 0.6318 - recall: 0.6627 - val_accuracy: 0.4938 - val_auc: 0.4874 - val_loss: 7.8981 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.6673 - auc: 0.7289 - loss: 1.3541 - precision: 0.6555 - recall: 0.6964 - val_accuracy: 0.4938 - val_auc: 0.4832 - val_loss: 6.9814 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7068 - auc: 0.7680 - loss: 0.7937 - precision: 0.6861 - recall: 0.7620 - val_accuracy: 0.7063 - val_auc: 0.7793 - val_loss: 0.9402 - val_precision: 0.6897 - val_recall: 0.7500
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6942 - auc: 0.7576 - loss: 0.7329 - precision: 0.7057 - recall: 0.6830 - val_accuracy: 0.6219 - val_auc: 0.6820 - val_loss: 2.8290 - val_precision: 0.8000 - val_recall: 0.3250
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6952 - auc: 0.7663 - loss: 0.6344 - precision: 0.6758 - recall: 0.7311 - val_accuracy: 0.7312 - val_auc: 0.7982 - val_loss: 1.6259 - val_precision: 0.7846 - val_recall: 0.6375
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.6996 - auc: 0.7688 - loss: 0.6176 - precision: 0.6861 - recall: 0.7691 - val_accuracy: 0.7312 - val_auc: 0.7796 - val_loss: 1.8877 - val_precision: 0.8426 - val_recall: 0.5688
#
# Training with d1=0.1, d2=0.4, lr=0.001, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 51s 5s/step - accuracy: 0.5757 - auc: 0.5959 - loss: 27.3010 - precision: 0.5711 - recall: 0.5608 - val_accuracy: 0.5250 - val_auc: 0.4051 - val_loss: 1.4407 - val_precision: 0.5128 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6483 - auc: 0.6963 - loss: 1.8472 - precision: 0.6414 - recall: 0.7027 - val_accuracy: 0.4656 - val_auc: 0.3964 - val_loss: 1.0260 - val_precision: 0.2609 - val_recall: 0.0375
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6864 - auc: 0.7447 - loss: 0.7058 - precision: 0.7029 - recall: 0.6673 - val_accuracy: 0.4750 - val_auc: 0.4353 - val_loss: 1.6521 - val_precision: 0.2500 - val_recall: 0.0250
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6688 - auc: 0.7141 - loss: 0.7324 - precision: 0.6625 - recall: 0.6682 - val_accuracy: 0.4469 - val_auc: 0.4019 - val_loss: 2.7613 - val_precision: 0.1600 - val_recall: 0.0250
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7193 - auc: 0.7868 - loss: 0.5834 - precision: 0.7351 - recall: 0.6901 - val_accuracy: 0.5000 - val_auc: 0.4346 - val_loss: 5.0340 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.1, d2=0.4, lr=0.0005, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - accuracy: 0.5413 - auc: 0.5538 - loss: 16.0243 - precision: 0.5532 - recall: 0.4957 - val_accuracy: 0.5219 - val_auc: 0.6212 - val_loss: 1.1454 - val_precision: 0.5112 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6439 - auc: 0.7059 - loss: 1.0182 - precision: 0.6194 - recall: 0.8282 - val_accuracy: 0.4938 - val_auc: 0.4222 - val_loss: 1.3241 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6700 - auc: 0.7616 - loss: 0.8021 - precision: 0.6639 - recall: 0.7359 - val_accuracy: 0.5031 - val_auc: 0.4781 - val_loss: 1.1684 - val_precision: 0.5714 - val_recall: 0.0250
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6926 - auc: 0.7724 - loss: 0.6009 - precision: 0.6615 - recall: 0.8134 - val_accuracy: 0.6812 - val_auc: 0.7915 - val_loss: 0.8377 - val_precision: 0.8295 - val_recall: 0.4563
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7263 - auc: 0.7981 - loss: 0.5782 - precision: 0.6890 - recall: 0.8184 - val_accuracy: 0.8281 - val_auc: 0.8816 - val_loss: 0.6920 - val_precision: 0.8221 - val_recall: 0.8375
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.7006 - auc: 0.7944 - loss: 0.5450 - precision: 0.6768 - recall: 0.7722 - val_accuracy: 0.8344 - val_auc: 0.8986 - val_loss: 0.7558 - val_precision: 0.8166 - val_recall: 0.8625
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6945 - auc: 0.7921 - loss: 0.5393 - precision: 0.6677 - recall: 0.7797 - val_accuracy: 0.8281 - val_auc: 0.9013 - val_loss: 0.8203 - val_precision: 0.7966 - val_recall: 0.8813
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.7289 - auc: 0.8306 - loss: 0.5139 - precision: 0.6990 - recall: 0.8202 - val_accuracy: 0.8344 - val_auc: 0.9050 - val_loss: 0.8323 - val_precision: 0.8242 - val_recall: 0.8500
#
# Training with d1=0.1, d2=0.4, lr=0.0005, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.6158 - auc: 0.6492 - loss: 3.3515 - precision: 0.6129 - recall: 0.6167 - val_accuracy: 0.4938 - val_auc: 0.6829 - val_loss: 1.4046 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6477 - auc: 0.6969 - loss: 1.3953 - precision: 0.6356 - recall: 0.6983 - val_accuracy: 0.5031 - val_auc: 0.6787 - val_loss: 0.9204 - val_precision: 0.6000 - val_recall: 0.0188
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6811 - auc: 0.7436 - loss: 0.6787 - precision: 0.6963 - recall: 0.6851 - val_accuracy: 0.4969 - val_auc: 0.6337 - val_loss: 0.7991 - val_precision: 0.4894 - val_recall: 0.1437
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6944 - auc: 0.7558 - loss: 0.6271 - precision: 0.6986 - recall: 0.7012 - val_accuracy: 0.5250 - val_auc: 0.6298 - val_loss: 0.9115 - val_precision: 0.5571 - val_recall: 0.2438
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6976 - auc: 0.7799 - loss: 0.5888 - precision: 0.6779 - recall: 0.7371 - val_accuracy: 0.5344 - val_auc: 0.6129 - val_loss: 1.3204 - val_precision: 0.5753 - val_recall: 0.2625
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7250 - auc: 0.8072 - loss: 0.5385 - precision: 0.7095 - recall: 0.7514 - val_accuracy: 0.5000 - val_auc: 0.6085 - val_loss: 1.9545 - val_precision: 0.5000 - val_recall: 0.1375
#
# Training with d1=0.1, d2=0.4, lr=0.0005, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 73s 7s/step - accuracy: 0.5776 - auc: 0.5857 - loss: 40.1732 - precision: 0.5847 - recall: 0.5547 - val_accuracy: 0.4094 - val_auc: 0.3668 - val_loss: 0.7280 - val_precision: 0.4162 - val_recall: 0.4500
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.6211 - auc: 0.6658 - loss: 1.9222 - precision: 0.6122 - recall: 0.6512 - val_accuracy: 0.5000 - val_auc: 0.2075 - val_loss: 1.1877 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7216 - auc: 0.7695 - loss: 0.7040 - precision: 0.7207 - recall: 0.7575 - val_accuracy: 0.4750 - val_auc: 0.3850 - val_loss: 2.2707 - val_precision: 0.3182 - val_recall: 0.0437
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7138 - auc: 0.7801 - loss: 0.6263 - precision: 0.7090 - recall: 0.7212 - val_accuracy: 0.4969 - val_auc: 0.4487 - val_loss: 4.4284 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.1, d2=0.4, lr=0.0005, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.6231 - auc: 0.6333 - loss: 14.2703 - precision: 0.6259 - recall: 0.6476 - val_accuracy: 0.6062 - val_auc: 0.8034 - val_loss: 0.7990 - val_precision: 0.5594 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7064 - auc: 0.7724 - loss: 0.7026 - precision: 0.7203 - recall: 0.7186 - val_accuracy: 0.7156 - val_auc: 0.8189 - val_loss: 0.5538 - val_precision: 0.7851 - val_recall: 0.5938
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6888 - auc: 0.7524 - loss: 0.6741 - precision: 0.6971 - recall: 0.6676 - val_accuracy: 0.5281 - val_auc: 0.7064 - val_loss: 0.9219 - val_precision: 0.8000 - val_recall: 0.0750
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7084 - auc: 0.7890 - loss: 0.6162 - precision: 0.7192 - recall: 0.7014 - val_accuracy: 0.5063 - val_auc: 0.6172 - val_loss: 1.5825 - val_precision: 1.0000 - val_recall: 0.0125
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7051 - auc: 0.7757 - loss: 0.6206 - precision: 0.7112 - recall: 0.7272 - val_accuracy: 0.5000 - val_auc: 0.6528 - val_loss: 2.2047 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.2, lr=0.001, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - accuracy: 0.6055 - auc: 0.6154 - loss: 29.1713 - precision: 0.5992 - recall: 0.6118 - val_accuracy: 0.5000 - val_auc: 0.7698 - val_loss: 1.0523 - val_precision: 0.5000 - val_recall: 0.0063
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.6590 - auc: 0.6785 - loss: 2.8254 - precision: 0.6507 - recall: 0.7406 - val_accuracy: 0.5531 - val_auc: 0.5593 - val_loss: 4.8362 - val_precision: 0.5282 - val_recall: 0.9937
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6476 - auc: 0.7077 - loss: 0.8769 - precision: 0.6490 - recall: 0.6542 - val_accuracy: 0.4844 - val_auc: 0.4642 - val_loss: 6.0758 - val_precision: 0.4857 - val_recall: 0.5312
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6901 - auc: 0.7787 - loss: 0.5898 - precision: 0.7354 - recall: 0.6090 - val_accuracy: 0.4625 - val_auc: 0.4463 - val_loss: 14.6864 - val_precision: 0.3000 - val_recall: 0.0562
#
# Training with d1=0.3, d2=0.2, lr=0.001, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 52s 5s/step - accuracy: 0.5443 - auc: 0.5676 - loss: 18.2508 - precision: 0.5354 - recall: 0.6087 - val_accuracy: 0.6750 - val_auc: 0.9216 - val_loss: 0.6012 - val_precision: 0.9000 - val_recall: 0.3938
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6177 - auc: 0.6853 - loss: 2.2033 - precision: 0.8258 - recall: 0.2918 - val_accuracy: 0.5594 - val_auc: 0.6241 - val_loss: 1.0194 - val_precision: 0.5812 - val_recall: 0.4250
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6146 - auc: 0.6712 - loss: 0.6896 - precision: 0.5729 - recall: 0.9483 - val_accuracy: 0.5000 - val_auc: 0.4812 - val_loss: 16.4745 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6538 - auc: 0.7400 - loss: 0.6271 - precision: 0.6024 - recall: 0.8903 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 32.7189 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.2, lr=0.001, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 73s 7s/step - accuracy: 0.5767 - auc: 0.5870 - loss: 64.5609 - precision: 0.5733 - recall: 0.5487 - val_accuracy: 0.4812 - val_auc: 0.2742 - val_loss: 3.1498 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.6508 - auc: 0.6669 - loss: 6.3110 - precision: 0.6507 - recall: 0.6736 - val_accuracy: 0.5375 - val_auc: 0.4966 - val_loss: 1.4938 - val_precision: 0.5207 - val_recall: 0.9438
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6819 - auc: 0.7152 - loss: 3.1549 - precision: 0.7076 - recall: 0.6721 - val_accuracy: 0.4875 - val_auc: 0.5255 - val_loss: 1.8931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7108 - auc: 0.7559 - loss: 1.2419 - precision: 0.7060 - recall: 0.7107 - val_accuracy: 0.5000 - val_auc: 0.3152 - val_loss: 4.0495 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7032 - auc: 0.7618 - loss: 0.8676 - precision: 0.6803 - recall: 0.7610 - val_accuracy: 0.5000 - val_auc: 0.4781 - val_loss: 9.4617 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.2, lr=0.001, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.5638 - auc: 0.5823 - loss: 40.4640 - precision: 0.5700 - recall: 0.6043 - val_accuracy: 0.5000 - val_auc: 0.6687 - val_loss: 1.4205 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6722 - auc: 0.7260 - loss: 2.1646 - precision: 0.6649 - recall: 0.7264 - val_accuracy: 0.5000 - val_auc: 0.3916 - val_loss: 1.4708 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6705 - auc: 0.7503 - loss: 0.7533 - precision: 0.6855 - recall: 0.6293 - val_accuracy: 0.5000 - val_auc: 0.5747 - val_loss: 1.6520 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6899 - auc: 0.7702 - loss: 0.6844 - precision: 0.6968 - recall: 0.6562 - val_accuracy: 0.5000 - val_auc: 0.5748 - val_loss: 1.4377 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.2, lr=0.0005, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 96s 9s/step - accuracy: 0.5619 - auc: 0.5890 - loss: 24.1332 - precision: 0.5541 - recall: 0.6008 - val_accuracy: 0.4938 - val_auc: 0.8964 - val_loss: 0.6728 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 97s 9s/step - accuracy: 0.6174 - auc: 0.7407 - loss: 0.9272 - precision: 0.7000 - recall: 0.3736 - val_accuracy: 0.6625 - val_auc: 0.7658 - val_loss: 0.6870 - val_precision: 0.6121 - val_recall: 0.8875
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 97s 9s/step - accuracy: 0.5125 - auc: 0.6810 - loss: 0.6595 - precision: 0.5787 - recall: 0.1344 - val_accuracy: 0.4563 - val_auc: 0.4283 - val_loss: 7.5747 - val_precision: 0.1818 - val_recall: 0.0250
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49934s 5547s/step - accuracy: 0.6587 - auc: 0.6984 - loss: 0.6226 - precision: 0.5991 - recall: 0.8646 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 18.2927 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.2, lr=0.0005, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 60s 5s/step - accuracy: 0.5532 - auc: 0.5867 - loss: 6.1436 - precision: 0.5624 - recall: 0.5758 - val_accuracy: 0.3969 - val_auc: 0.3780 - val_loss: 0.7624 - val_precision: 0.3299 - val_recall: 0.2000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.6721 - auc: 0.7316 - loss: 1.4590 - precision: 0.6758 - recall: 0.6305 - val_accuracy: 0.4938 - val_auc: 0.2703 - val_loss: 0.8566 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - accuracy: 0.6954 - auc: 0.7580 - loss: 0.7101 - precision: 0.6852 - recall: 0.7090 - val_accuracy: 0.5000 - val_auc: 0.3379 - val_loss: 0.7278 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7257 - auc: 0.7941 - loss: 0.5680 - precision: 0.6947 - recall: 0.8049 - val_accuracy: 0.5000 - val_auc: 0.3468 - val_loss: 0.7874 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7166 - auc: 0.8000 - loss: 0.5471 - precision: 0.6899 - recall: 0.7484 - val_accuracy: 0.5000 - val_auc: 0.3612 - val_loss: 1.3268 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.7361 - auc: 0.8080 - loss: 0.5355 - precision: 0.7025 - recall: 0.8060 - val_accuracy: 0.4969 - val_auc: 0.3706 - val_loss: 2.6179 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.2, lr=0.0005, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - accuracy: 0.5613 - auc: 0.5689 - loss: 41.5242 - precision: 0.5433 - recall: 0.5999 - val_accuracy: 0.5000 - val_auc: 0.4441 - val_loss: 2.2412 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 78s 8s/step - accuracy: 0.6634 - auc: 0.7151 - loss: 1.0025 - precision: 0.6818 - recall: 0.6397 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 4.3522 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.6597 - auc: 0.7564 - loss: 0.6257 - precision: 0.7189 - recall: 0.5372 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 8.4975 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6869 - auc: 0.7635 - loss: 0.6021 - precision: 0.6628 - recall: 0.7891 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 16.1118 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.2, lr=0.0005, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 56s 5s/step - accuracy: 0.5807 - auc: 0.5888 - loss: 15.8632 - precision: 0.5850 - recall: 0.5300 - val_accuracy: 0.4906 - val_auc: 0.6468 - val_loss: 1.0070 - val_precision: 0.3333 - val_recall: 0.0188
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.6594 - auc: 0.7177 - loss: 1.1702 - precision: 0.6638 - recall: 0.6606 - val_accuracy: 0.4906 - val_auc: 0.6860 - val_loss: 1.1443 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7173 - auc: 0.7749 - loss: 0.6345 - precision: 0.7195 - recall: 0.7035 - val_accuracy: 0.5000 - val_auc: 0.5874 - val_loss: 2.4373 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7178 - auc: 0.7877 - loss: 0.6190 - precision: 0.7077 - recall: 0.7400 - val_accuracy: 0.5000 - val_auc: 0.5142 - val_loss: 3.5156 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.4, lr=0.001, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.6005 - auc: 0.6164 - loss: 25.0441 - precision: 0.6071 - recall: 0.6122 - val_accuracy: 0.4969 - val_auc: 0.5262 - val_loss: 3.4471 - val_precision: 0.4444 - val_recall: 0.0250
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6528 - auc: 0.7037 - loss: 3.5020 - precision: 0.6968 - recall: 0.5719 - val_accuracy: 0.5000 - val_auc: 0.4938 - val_loss: 8.9688 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6820 - auc: 0.7434 - loss: 1.3712 - precision: 0.6714 - recall: 0.6963 - val_accuracy: 0.5000 - val_auc: 0.4177 - val_loss: 3.0695 - val_precision: 0.5000 - val_recall: 0.0125
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6942 - auc: 0.7709 - loss: 0.6588 - precision: 0.6643 - recall: 0.7869 - val_accuracy: 0.5094 - val_auc: 0.5165 - val_loss: 5.3829 - val_precision: 0.5882 - val_recall: 0.0625
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6667 - auc: 0.7479 - loss: 0.6399 - precision: 0.6370 - recall: 0.7687 - val_accuracy: 0.6031 - val_auc: 0.6275 - val_loss: 4.3618 - val_precision: 0.6813 - val_recall: 0.3875
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7041 - auc: 0.8076 - loss: 0.5562 - precision: 0.6732 - recall: 0.8394 - val_accuracy: 0.7063 - val_auc: 0.7417 - val_loss: 4.0042 - val_precision: 0.7089 - val_recall: 0.7000
#
# Training with d1=0.3, d2=0.4, lr=0.001, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 52s 5s/step - accuracy: 0.5270 - auc: 0.5470 - loss: 9.8527 - precision: 0.5354 - recall: 0.6008 - val_accuracy: 0.7344 - val_auc: 0.9874 - val_loss: 0.5959 - val_precision: 1.0000 - val_recall: 0.4688
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6198 - auc: 0.6789 - loss: 1.7375 - precision: 0.5939 - recall: 0.7076 - val_accuracy: 0.5000 - val_auc: 0.9737 - val_loss: 0.7182 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.6000 - auc: 0.6192 - loss: 0.9355 - precision: 0.6152 - recall: 0.5904 - val_accuracy: 0.5000 - val_auc: 0.9543 - val_loss: 2.0222 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6337 - auc: 0.6937 - loss: 0.8509 - precision: 0.6305 - recall: 0.6247 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 3.5466 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.4, lr=0.001, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.5729 - auc: 0.6071 - loss: 59.0550 - precision: 0.5591 - recall: 0.6045 - val_accuracy: 0.5312 - val_auc: 0.5548 - val_loss: 4.2660 - val_precision: 0.5161 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6839 - auc: 0.7437 - loss: 2.8268 - precision: 0.6775 - recall: 0.6811 - val_accuracy: 0.4844 - val_auc: 0.5228 - val_loss: 1.3370 - val_precision: 0.4615 - val_recall: 0.1875
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6833 - auc: 0.7627 - loss: 1.1571 - precision: 0.7465 - recall: 0.5615 - val_accuracy: 0.6219 - val_auc: 0.6582 - val_loss: 2.4108 - val_precision: 0.6010 - val_recall: 0.7250
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.6772 - auc: 0.7498 - loss: 0.9514 - precision: 0.7444 - recall: 0.5306 - val_accuracy: 0.4938 - val_auc: 0.5095 - val_loss: 6.0990 - val_precision: 0.4914 - val_recall: 0.3562
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - accuracy: 0.6710 - auc: 0.7453 - loss: 0.7621 - precision: 0.7198 - recall: 0.5421 - val_accuracy: 0.4750 - val_auc: 0.4668 - val_loss: 10.9918 - val_precision: 0.3889 - val_recall: 0.0875
#
# Training with d1=0.3, d2=0.4, lr=0.001, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.5473 - auc: 0.5678 - loss: 39.2783 - precision: 0.5265 - recall: 0.5122 - val_accuracy: 0.7344 - val_auc: 0.8358 - val_loss: 0.5665 - val_precision: 0.6761 - val_recall: 0.9000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6828 - auc: 0.7355 - loss: 0.9203 - precision: 0.6797 - recall: 0.7239 - val_accuracy: 0.5000 - val_auc: 0.7027 - val_loss: 2.3304 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7047 - auc: 0.7655 - loss: 0.7487 - precision: 0.6780 - recall: 0.7416 - val_accuracy: 0.5000 - val_auc: 0.3678 - val_loss: 3.9258 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.6434 - auc: 0.7095 - loss: 0.7578 - precision: 0.6264 - recall: 0.7270 - val_accuracy: 0.5000 - val_auc: 0.4906 - val_loss: 9.1405 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.4, lr=0.0005, opt=adam, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 77s 7s/step - accuracy: 0.5956 - auc: 0.6191 - loss: 9.7538 - precision: 0.6006 - recall: 0.5901 - val_accuracy: 0.4781 - val_auc: 0.2909 - val_loss: 1.3987 - val_precision: 0.1111 - val_recall: 0.0063
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6364 - auc: 0.6938 - loss: 2.8074 - precision: 0.6086 - recall: 0.7408 - val_accuracy: 0.5000 - val_auc: 0.4815 - val_loss: 1.9538 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6951 - auc: 0.7589 - loss: 1.0926 - precision: 0.6622 - recall: 0.7636 - val_accuracy: 0.5000 - val_auc: 0.3567 - val_loss: 3.4996 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6639 - auc: 0.7541 - loss: 0.6345 - precision: 0.7470 - recall: 0.4962 - val_accuracy: 0.5000 - val_auc: 0.3953 - val_loss: 6.9367 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Training with d1=0.3, d2=0.4, lr=0.0005, opt=adam, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.6103 - auc: 0.6197 - loss: 6.4425 - precision: 0.6290 - recall: 0.6131 - val_accuracy: 0.5000 - val_auc: 0.5345 - val_loss: 1.0300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.6697 - auc: 0.7236 - loss: 1.3661 - precision: 0.7087 - recall: 0.5987 - val_accuracy: 0.4969 - val_auc: 0.2256 - val_loss: 0.8914 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.6744 - auc: 0.7392 - loss: 0.7072 - precision: 0.6941 - recall: 0.6281 - val_accuracy: 0.4219 - val_auc: 0.3708 - val_loss: 0.7381 - val_precision: 0.4339 - val_recall: 0.5125
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.7218 - auc: 0.7551 - loss: 0.6111 - precision: 0.6990 - recall: 0.8150 - val_accuracy: 0.4250 - val_auc: 0.4097 - val_loss: 0.7217 - val_precision: 0.2000 - val_recall: 0.0500
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.7345 - auc: 0.7986 - loss: 0.5490 - precision: 0.6962 - recall: 0.7976 - val_accuracy: 0.5188 - val_auc: 0.5913 - val_loss: 0.8180 - val_precision: 0.8000 - val_recall: 0.0500
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.7175 - auc: 0.7814 - loss: 0.5638 - precision: 0.6990 - recall: 0.7747 - val_accuracy: 0.5531 - val_auc: 0.6774 - val_loss: 1.1616 - val_precision: 0.8696 - val_recall: 0.1250
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.7229 - auc: 0.7958 - loss: 0.5581 - precision: 0.7222 - recall: 0.7101 - val_accuracy: 0.5656 - val_auc: 0.7132 - val_loss: 1.7164 - val_precision: 0.8621 - val_recall: 0.1562
#
# Training with d1=0.3, d2=0.4, lr=0.0005, opt=rmsprop, filters=(16, 32, 64)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 75s 7s/step - accuracy: 0.5704 - auc: 0.5854 - loss: 36.0779 - precision: 0.5805 - recall: 0.5430 - val_accuracy: 0.4938 - val_auc: 0.4905 - val_loss: 5.8473 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6496 - auc: 0.7086 - loss: 2.0896 - precision: 0.6492 - recall: 0.6449 - val_accuracy: 0.4969 - val_auc: 0.3409 - val_loss: 3.1990 - val_precision: 0.3333 - val_recall: 0.0063
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7287 - auc: 0.8023 - loss: 0.7170 - precision: 0.7385 - recall: 0.7205 - val_accuracy: 0.4969 - val_auc: 0.4524 - val_loss: 4.1411 - val_precision: 0.3333 - val_recall: 0.0063
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7000 - auc: 0.7595 - loss: 0.8343 - precision: 0.7267 - recall: 0.6482 - val_accuracy: 0.5000 - val_auc: 0.4340 - val_loss: 4.8531 - val_precision: 0.5000 - val_recall: 0.0125
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7021 - auc: 0.7644 - loss: 0.6909 - precision: 0.7049 - recall: 0.7336 - val_accuracy: 0.5063 - val_auc: 0.4786 - val_loss: 6.7956 - val_precision: 0.6667 - val_recall: 0.0250
#
# Training with d1=0.3, d2=0.4, lr=0.0005, opt=rmsprop, filters=(8, 16, 32)
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 52s 5s/step - accuracy: 0.5588 - auc: 0.5700 - loss: 29.8059 - precision: 0.5730 - recall: 0.5726 - val_accuracy: 0.6031 - val_auc: 0.6470 - val_loss: 0.6891 - val_precision: 0.5575 - val_recall: 1.0000
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6832 - auc: 0.7679 - loss: 0.5930 - precision: 0.6624 - recall: 0.7912 - val_accuracy: 0.5906 - val_auc: 0.5805 - val_loss: 0.6735 - val_precision: 0.5644 - val_recall: 0.7937
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.6959 - auc: 0.7742 - loss: 0.5859 - precision: 0.6721 - recall: 0.7224 - val_accuracy: 0.4969 - val_auc: 0.3943 - val_loss: 1.5305 - val_precision: 0.4815 - val_recall: 0.0812
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7169 - auc: 0.8040 - loss: 0.5514 - precision: 0.7089 - recall: 0.7342 - val_accuracy: 0.4844 - val_auc: 0.3900 - val_loss: 6.1741 - val_precision: 0.1429 - val_recall: 0.0063
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.7269 - auc: 0.7946 - loss: 0.5907 - precision: 0.7314 - recall: 0.7225 - val_accuracy: 0.5000 - val_auc: 0.4686 - val_loss: 10.6323 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ## 5) final baseline model (with validation set)

# %%
model_final = build_model(
        'adam',
        filters=(8, 16, 32),
        dropout1=0.1,
        dropout2=0.2,
        dropout3=0.5,
        learning_rate= 0.0005
    )

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history_final = model_final.fit(
        train_data_gen_aug,
        validation_data=val_data_gen, #including validation dataset 
        epochs=30,
        batch_size= batch_size,
        callbacks=[early_stop],
        verbose=1)
# Out:
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 69s 5s/step - accuracy: 0.6205 - auc: 0.6371 - loss: 10.5211 - precision: 0.6077 - recall: 0.5883 - val_accuracy: 0.3050 - val_auc: 0.2876 - val_loss: 1.0185 - val_precision: 0.3227 - val_recall: 0.3550
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 66s 5s/step - accuracy: 0.6921 - auc: 0.7368 - loss: 1.3194 - precision: 0.6981 - recall: 0.6942 - val_accuracy: 0.4975 - val_auc: 0.3565 - val_loss: 2.4018 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 67s 5s/step - accuracy: 0.7185 - auc: 0.7884 - loss: 0.6792 - precision: 0.7460 - recall: 0.6882 - val_accuracy: 0.4975 - val_auc: 0.4612 - val_loss: 4.9418 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 64s 5s/step - accuracy: 0.7232 - auc: 0.7849 - loss: 0.6129 - precision: 0.7328 - recall: 0.6991 - val_accuracy: 0.4975 - val_auc: 0.4875 - val_loss: 7.2843 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step - accuracy: 0.7180 - auc: 0.7929 - loss: 0.5927 - precision: 0.7104 - recall: 0.7419 - val_accuracy: 0.4975 - val_auc: 0.4925 - val_loss: 8.1297 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step - accuracy: 0.7092 - auc: 0.7900 - loss: 0.5948 - precision: 0.7070 - recall: 0.6874 - val_accuracy: 0.5000 - val_auc: 0.4900 - val_loss: 9.1973 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
# List of metrics to plot
metrics_to_plot = ['accuracy', 'precision', 'recall', 'auc']

plt.figure(figsize=(14, 10))

for i, metric in enumerate(metrics_to_plot):
    plt.subplot(2, 2, i + 1)
    plt.plot(history_final.history[metric], label=f'Train {metric}')
    #plt.plot(history_final.history[f'val_{metric}'], label=f'Val {metric}')
    plt.title(f'{metric.capitalize()} over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model
model_final.save("final_model.h5")
baselinemodel = load_model("final_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory
test_data = image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    batch_size=batch_size
).map(lambda x, y: (custom_preprocessing(x), y))

true_labels = []
predicted_labels = []

for images, labels in test_data:
    predictions = (baselinemodel.predict(images) > 0.5).astype("int32").flatten()
    true_labels.extend(labels.numpy())
    predicted_labels.extend(predictions)

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
ConfusionMatrixDisplay(cm).plot()
# Out:
# Found 200 files belonging to 2 classes.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step

# %%
print(
